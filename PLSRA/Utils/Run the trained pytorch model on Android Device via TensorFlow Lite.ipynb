# %% [markdown]
# # Run the trained model on Android Device Via TensorFlow

# %% [markdown]
# Pytorch is very usefull for developing and testing model and for research purposes but a minor downside of PyTorch is that it is not very usefull for deployment of the AI Models so therefore we will use Google's Tensorflow to deploy model on Android Device so we will now have to convert the model to tensorflow so that we can deploy that to Android

# %% [markdown]
# ## Convert from PyTorch to ONNX
# ONNX (Open Neural Network Exchange) is open format for exchange of Deep Learning model between different Frameworks. In other words it is format which is widely used for exchanging one model from one framework to other framework. We will first convert model from Pytorch to ONNX so we can transfer it to another framework.
# The Process of converting to ONNX is that we make a random dummy input and pass it through the model in pytorch and then pass it  throught the function of onnx export to export it to a .onnx file. The shape of the dummy input should be (1, shape of single images) in detail the input would be (1, number of color channels, width of picture , height of picture )`

# %%
# helper functions for this notebook
def gvd(variable):
    print("The data type of this variable is " + str(type(variable)))
import time
def mills():
    return int(round(time.time() * 1000))

# %% [markdown]
# ### Loading Pytorch Model

# %%
# !pip list | grep 'torch'
# Out:
# torch                         1.7.0+cu101
# torchsummary                  1.5.1
# torchtext                     0.3.1
# torchvision                   0.8.1+cu101

# %%
import torch
import torchvision
import torch.nn as nn

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# Load model from torchvision model zoo

# %%
# You can load model from torchvision models or below you can load local model file.
model = torchvision.models.mobilenet_v2(pretrained=True, progress=True)
# Out:
# Downloading: "https://download.pytorch.org/models/mobilenet_v2-b0353104.pth" to /root/.cache/torch/hub/checkpoints/mobilenet_v2-b0353104.pth
# HBox(children=(FloatProgress(value=0.0, max=14212972.0), HTML(value='')))

# %% [markdown]
# OR
#
#
# **Load model from local file**
#
# for more help GOTO: https://pytorch.org/tutorials/beginner/saving_loading_models.html

# %%
from torch import nn
import torch.onnx

class Generator(nn.Module):
    def __init__(self):

        super(Generator, self).__init__()

        self.conv1_1 = torch.nn.Conv2d(3, 8, kernel_size=3, padding=1).to(dtype=torch.float)
        self.bn1_1 = torch.nn.BatchNorm2d(8).to(dtype=torch.float)
        self.relu1_1 = torch.nn.ReLU()

        self.conv2_1 = torch.nn.Conv2d(8, 8, kernel_size=3, padding=1).to(dtype=torch.float)
        self.bn2_1 = torch.nn.BatchNorm2d(8).to(dtype=torch.float)
        self.relu2_1 = torch.nn.ReLU()

        self.conv3_1 = torch.nn.Conv2d(8, 32, kernel_size=3, padding=1).to(dtype=torch.float)
        self.relu3_1 = torch.nn.ReLU()
        self.pixel_shuffle3_1 = torch.nn.PixelShuffle(2)

        self.conv4_1 = torch.nn.Conv2d(8, 32, kernel_size=3, padding=1).to(dtype=torch.float)
        self.relu4_1 = torch.nn.ReLU()
        self.pixel_shuffle4_1 = torch.nn.PixelShuffle(2)

        self.conv5_1 = torch.nn.Conv2d(8, 32, kernel_size=3, padding=1).to(dtype=torch.float)
        self.relu5_1 = torch.nn.ReLU()
        self.pixel_shuffle5_1 = torch.nn.PixelShuffle(2)

        self.conv6_1 = torch.nn.Conv2d(8, 3, kernel_size=3, padding=1).to(dtype=torch.float)

    def forward(self, x):
        x = self.conv1_1(x)
        x = self.bn1_1(x)
        x = self.relu1_1(x)

        x = self.conv2_1(x)
        x = self.bn2_1(x)
        x = self.relu2_1(x)

        x = self.conv3_1(x)
        x = self.relu3_1(x)
        x = self.pixel_shuffle3_1(x)

        x = self.conv4_1(x)
        x = self.relu4_1(x)
        x = self.pixel_shuffle4_1(x)

        x = self.conv5_1(x)
        x = self.relu5_1(x)
        x = self.pixel_shuffle5_1(x)

        x = self.conv6_1(x)
        
        out = (torch.tanh(x) + 1) / 2

        return out

torch_model = Generator()
torch_model.cuda()
torch_model.load_state_dict(torch.load("/content/drive/My Drive/data/epochs/netG_epoch_8_90.pth"))
torch_model.eval()
# Out:
# Generator(
#   (conv1_1): Conv2d(3, 8, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (bn1_1): BatchNorm2d(8, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (relu1_1): ReLU()
#   (conv2_1): Conv2d(8, 8, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (bn2_1): BatchNorm2d(8, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (relu2_1): ReLU()
#   (conv3_1): Conv2d(8, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (relu3_1): ReLU()
#   (pixel_shuffle3_1): PixelShuffle(upscale_factor=2)
#   (conv4_1): Conv2d(8, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (relu4_1): ReLU()
#   (pixel_shuffle4_1): PixelShuffle(upscale_factor=2)
#   (conv5_1): Conv2d(8, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (relu5_1): ReLU()
#   (pixel_shuffle5_1): PixelShuffle(upscale_factor=2)
#   (conv6_1): Conv2d(8, 3, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
# )

# %% [markdown]
# ### Perform simple PyTorch inference

# %%
image_size = 256 # size of input image
color_channels = 3
batch_size = 1
dummy_input = torch.rand(batch_size, color_channels, image_size, image_size)
print(dummy_input.size())
print((dummy_input.cuda()).size())
# Out:
# torch.Size([1, 3, 256, 256])
# torch.Size([1, 3, 256, 256])

# %%
# performs inference with pytorch
start_time = mills()
output = torch_model(dummy_input.cuda())
end_time = mills()
print("model single inference in milliSeconds ", end_time - start_time)
print("model output shape: ", output.shape)
# Out:
# model single inference in milliSeconds  3
# model output shape:  torch.Size([1, 3, 2048, 2048])

# %% [markdown]
# ## Convert to ONNX model

# %%
# Export the model
torch_out = torch.onnx._export(torch_model,             # model being run
                              dummy_input.cuda(),                       # model input (or a tuple for multiple inputs)
                              'eye_state_model_ONNX.onnx', # where to save the model (can be a file or file-like object)
                              export_params=True,       # store the trained parameter weights inside the model file
                              input_names=['main_input'],  # specify the name of input layer in onnx model
                              output_names=['main_output'])     # specify the name of input layer in onnx model

# %% [markdown]
# ### Run ONNX model with ONNX runtime

# %% [markdown]
# OnnxRuntime is used for running ONNX model

# %%
# install onnxruntime
# !pip install --upgrade onnxruntime
# Out:
# Collecting onnxruntime
#   Downloading https://files.pythonhosted.org/packages/91/a5/a70b05bc5a6037e0bf29d21828945a49fa4d341690c8ae7f01a62a177a2b/onnxruntime-1.5.2-cp36-cp36m-manylinux2014_x86_64.whl (3.8MB)
#      |████████████████████████████████| 3.8MB 4.8MB/s
# Requirement already satisfied, skipping upgrade: numpy>=1.16.6 in /usr/local/lib/python3.6/dist-packages (from onnxruntime) (1.18.5)
# Requirement already satisfied, skipping upgrade: protobuf in /usr/local/lib/python3.6/dist-packages (from onnxruntime) (3.12.4)
# Requirement already satisfied, skipping upgrade: six>=1.9 in /usr/local/lib/python3.6/dist-packages (from protobuf->onnxruntime) (1.15.0)
# Requirement already satisfied, skipping upgrade: setuptools in /usr/local/lib/python3.6/dist-packages (from protobuf->onnxruntime) (50.3.2)
# Installing collected packages: onnxruntime
# Successfully installed onnxruntime-1.5.2

# %%
import onnxruntime as nxrun

sess = nxrun.InferenceSession('/content/eye_state_model_ONNX.onnx')
input_name = sess.get_inputs()[0].name
output_name = sess.get_outputs()[0].name
start_time = mills()
# run onnx model with onnx runtime python
result = sess.run(None, {input_name: dummy_input.numpy()})

end_time = mills()
print("model single inference in milliSeconds on onnxruntime", end_time - start_time)
print("Output", result)
# Out:
# model single inference in milliSeconds on onnxruntime 666
# Output [array([[[[0.43348402, 0.4199896 , 0.41498637, ..., 0.35747483,
#           0.31060505, 0.3940094 ],
#          [0.39806074, 0.40101653, 0.42159224, ..., 0.28493536,
#           0.2831241 , 0.32416904],
#          [0.3988735 , 0.4192746 , 0.39254513, ..., 0.24770582,
#           0.24658152, 0.30567044],
#          ...,
#          [0.40748838, 0.42893073, 0.45143926, ..., 0.5031651 ,
#           0.47874892, 0.46750182],
#          [0.39659277, 0.4151328 , 0.43215007, ..., 0.4823483 ,
#           0.46379876, 0.45471627],
#          [0.38823447, 0.37931353, 0.42069522, ..., 0.45294517,
#           0.44677478, 0.44986475]],
#
#         [[0.45000586, 0.44163433, 0.43215123, ..., 0.33709872,
#           0.34361   , 0.3636375 ],
#          [0.42680627, 0.43772098, 0.43013808, ..., 0.3504155 ,
#           0.32852006, 0.36744022],
#          [0.4416224 , 0.42279786, 0.4027039 , ..., 0.28841937,
#           0.28787106, 0.3319966 ],
#          ...,
#          [0.50858176, 0.53700966, 0.51290274, ..., 0.65669465,
#           0.6492565 , 0.5963343 ],
#          [0.50811005, 0.52206975, 0.5117663 , ..., 0.65404737,
#           0.6409583 , 0.6093768 ],
#          [0.49453163, 0.50170916, 0.48844546, ..., 0.58998007,
#           0.57768553, 0.5573234 ]],
#
#         [[0.48519966, 0.47035927, 0.4515349 , ..., 0.40912145,
#           0.39181113, 0.4148354 ],
#          [0.45953986, 0.47712716, 0.44091493, ..., 0.40240514,
#           0.36502993, 0.4054525 ],
#          [0.44699377, 0.43177977, 0.40794006, ..., 0.3584972 ,
#           0.3381425 , 0.36444932],
#          ...,
#          [0.58418566, 0.6055358 , 0.5641982 , ..., 0.74139464,
#           0.7393655 , 0.6698055 ],
#          [0.593908  , 0.60024154, 0.5693076 , ..., 0.75110376,
#           0.75267625, 0.6792095 ],
#          [0.5542367 , 0.56807953, 0.5481502 , ..., 0.6763379 ,
#           0.6736067 , 0.62465835]]]], dtype=float32)]

# %% [markdown]
# ## Convert from ONNX to TensorFlow FreezeGraph

# %% [markdown]
# **We will use onnx-tf to convert model**
#
# onnx_tf is the library build by onnx team which is used to transfer the model from onnx to tensorflow it can create a backend to enable the model to run with tensorflow. We will first load the saved .onnx model file with onnx.load and the by using prepare function of onnx_tf prepare that loaded model to be run by tensorflow. and by using the export_graph function of that prepared backend we can export this model in a file format with .tf extension supported by Original Tensorflow

# %%
# install onnx and onnx-tf
# !pip install --upgrade onnx | tail -n 2
# !pip install  onnx-tf==1.5.0 | tail -n 2
# Out:
# Installing collected packages: onnx
# Successfully installed onnx-1.7.0
# Installing collected packages: onnx-tf
# Successfully installed onnx-tf-1.5.0

# %%
# Tell google colab to use tensorflow version 1.x
# %tensorflow_version 1.x
# Out:
# TensorFlow 1.x selected.

# %%
# see versions of all tensorflow libraries installed
# !pip list | grep 'flow'
# Out:
# mesh-tensorflow               0.1.12
# tensorflow                    1.15.2
# tensorflow-addons             0.8.3
# tensorflow-datasets           4.0.1
# tensorflow-estimator          1.15.1
# tensorflow-gan                2.0.0
# tensorflow-gcs-config         2.3.0
# tensorflow-hub                0.10.0
# tensorflow-metadata           0.24.0
# tensorflow-privacy            0.2.2
# tensorflow-probability        0.7.0

# %%
import onnx
import tensorflow as tf

# %%
# Either convert onnx to tensorflow protobuf model by using command
# -i defined input model -o defines output model name
# !onnx-tf convert -i "/content/eye_state_model_ONNX.onnx" -o  '/content/eye_state_model_tensorFlow.pb'
# Out:
# /usr/local/lib/python3.6/dist-packages/onnx_tf/common/__init__.py:89: UserWarning: onnx_tf.common.get_outputs_names is deprecated. It will be removed in future release. Use TensorflowGraph.get_outputs_names instead.
#   warnings.warn(message)
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/onnx_tf/handlers/backend/ceil.py:10: The name tf.ceil is deprecated. Please use tf.math.ceil instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/onnx_tf/handlers/backend/depth_to_space.py:12: The name tf.depth_to_space is deprecated. Please use tf.compat.v1.depth_to_space instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/onnx_tf/handlers/backend/erf.py:9: The name tf.erf is deprecated. Please use tf.math.erf instead.
#
# WARNING:tensorflow:
# The TensorFlow contrib module will not be included in TensorFlow 2.0.
# For more information, please see:
#   * https://github.com/tensorflow/community/blob/master/rfcs/20180907-contrib-sunset.md
#   * https://github.com/tensorflow/addons
#   * https://github.com/tensorflow/io (for I/O related ops)
# If you depend on functionality not listed there, please file an issue.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/onnx_tf/handlers/backend/is_nan.py:9: The name tf.is_nan is deprecated. Please use tf.math.is_nan instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/onnx_tf/handlers/backend/log.py:10: The name tf.log is deprecated. Please use tf.math.log instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/onnx_tf/handlers/backend/random_normal.py:9: The name tf.random_normal is deprecated. Please use tf.random.normal instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/onnx_tf/handlers/backend/random_uniform.py:9: The name tf.random_uniform is deprecated. Please use tf.random.uniform instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/onnx_tf/handlers/backend/reciprocal.py:10: The name tf.reciprocal is deprecated. Please use tf.math.reciprocal instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/onnx_tf/handlers/backend/space_to_depth.py:12: The name tf.space_to_depth is deprecated. Please use tf.compat.v1.space_to_depth instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/onnx_tf/handlers/backend/upsample.py:15: The name tf.image.resize_images is deprecated. Please use tf.image.resize instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/onnx_tf/handlers/backend/xor.py:10: The name tf.logical_xor is deprecated. Please use tf.math.logical_xor instead.
#
# /usr/local/lib/python3.6/dist-packages/onnx_tf/common/handler_helper.py:37: UserWarning: Unknown op ConstantFill in domain `ai.onnx`.
#   handler.ONNX_OP, handler.DOMAIN or "ai.onnx"))
# /usr/local/lib/python3.6/dist-packages/onnx_tf/common/handler_helper.py:34: UserWarning: Fail to get since_version of ConvInteger in domain `` with max_inclusive_version=9. Set to 1.
#   handler.ONNX_OP, handler.DOMAIN, version))
# /usr/local/lib/python3.6/dist-packages/onnx_tf/common/handler_helper.py:34: UserWarning: Fail to get since_version of DequantizeLinear in domain `` with max_inclusive_version=9. Set to 1.
#   handler.ONNX_OP, handler.DOMAIN, version))
# /usr/local/lib/python3.6/dist-packages/onnx_tf/common/handler_helper.py:34: UserWarning: Fail to get since_version of GatherND in domain `` with max_inclusive_version=9. Set to 1.
#   handler.ONNX_OP, handler.DOMAIN, version))
# /usr/local/lib/python3.6/dist-packages/onnx_tf/common/handler_helper.py:37: UserWarning: Unknown op ImageScaler in domain `ai.onnx`.
#   handler.ONNX_OP, handler.DOMAIN or "ai.onnx"))
# /usr/local/lib/python3.6/dist-packages/onnx_tf/common/handler_helper.py:34: UserWarning: Fail to get since_version of IsInf in domain `` with max_inclusive_version=9. Set to 1.
#   handler.ONNX_OP, handler.DOMAIN, version))
# /usr/local/lib/python3.6/dist-packages/onnx_tf/common/handler_helper.py:34: UserWarning: Fail to get since_version of MatMulInteger in domain `` with max_inclusive_version=9. Set to 1.
#   handler.ONNX_OP, handler.DOMAIN, version))
# /usr/local/lib/python3.6/dist-packages/onnx_tf/common/handler_helper.py:34: UserWarning: Fail to get since_version of Mod in domain `` with max_inclusive_version=9. Set to 1.
#   handler.ONNX_OP, handler.DOMAIN, version))
# /usr/local/lib/python3.6/dist-packages/onnx_tf/common/handler_helper.py:34: UserWarning: Fail to get since_version of NonMaxSuppression in domain `` with max_inclusive_version=9. Set to 1.
#   handler.ONNX_OP, handler.DOMAIN, version))
# /usr/local/lib/python3.6/dist-packages/onnx_tf/common/handler_helper.py:34: UserWarning: Fail to get since_version of QLinearConv in domain `` with max_inclusive_version=9. Set to 1.
#   handler.ONNX_OP, handler.DOMAIN, version))
# /usr/local/lib/python3.6/dist-packages/onnx_tf/common/handler_helper.py:34: UserWarning: Fail to get since_version of QLinearMatMul in domain `` with max_inclusive_version=9. Set to 1.
#   handler.ONNX_OP, handler.DOMAIN, version))
# /usr/local/lib/python3.6/dist-packages/onnx_tf/common/handler_helper.py:34: UserWarning: Fail to get since_version of QuantizeLinear in domain `` with max_inclusive_version=9. Set to 1.
#   handler.ONNX_OP, handler.DOMAIN, version))
# /usr/local/lib/python3.6/dist-packages/onnx_tf/common/handler_helper.py:34: UserWarning: Fail to get since_version of Range in domain `` with max_inclusive_version=9. Set to 1.
#   handler.ONNX_OP, handler.DOMAIN, version))
# /usr/local/lib/python3.6/dist-packages/onnx_tf/common/handler_helper.py:34: UserWarning: Fail to get since_version of Resize in domain `` with max_inclusive_version=9. Set to 1.
#   handler.ONNX_OP, handler.DOMAIN, version))
# /usr/local/lib/python3.6/dist-packages/onnx_tf/common/handler_helper.py:34: UserWarning: Fail to get since_version of ReverseSequence in domain `` with max_inclusive_version=9. Set to 1.
#   handler.ONNX_OP, handler.DOMAIN, version))
# /usr/local/lib/python3.6/dist-packages/onnx_tf/common/handler_helper.py:34: UserWarning: Fail to get since_version of Round in domain `` with max_inclusive_version=9. Set to 1.
#   handler.ONNX_OP, handler.DOMAIN, version))
# /usr/local/lib/python3.6/dist-packages/onnx_tf/common/handler_helper.py:34: UserWarning: Fail to get since_version of ScatterElements in domain `` with max_inclusive_version=9. Set to 1.
#   handler.ONNX_OP, handler.DOMAIN, version))
# /usr/local/lib/python3.6/dist-packages/onnx_tf/common/handler_helper.py:34: UserWarning: Fail to get since_version of ScatterND in domain `` with max_inclusive_version=9. Set to 1.
#   handler.ONNX_OP, handler.DOMAIN, version))
# /usr/local/lib/python3.6/dist-packages/onnx_tf/common/handler_helper.py:34: UserWarning: Fail to get since_version of ThresholdedRelu in domain `` with max_inclusive_version=9. Set to 1.
#   handler.ONNX_OP, handler.DOMAIN, version))
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/onnx_tf/backend.py:123: The name tf.placeholder is deprecated. Please use tf.compat.v1.placeholder instead.
#
# 2020-11-06 12:02:57.288569: I tensorflow/core/platform/profile_utils/cpu_utils.cc:94] CPU Frequency: 2200000000 Hz
# 2020-11-06 12:02:57.288789: I tensorflow/compiler/xla/service/service.cc:168] XLA service 0x6c8e380 initialized for platform Host (this does not guarantee that XLA will be used). Devices:
# 2020-11-06 12:02:57.288820: I tensorflow/compiler/xla/service/service.cc:176]   StreamExecutor device (0): Host, Default Version
# 2020-11-06 12:02:57.293038: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcuda.so.1
# 2020-11-06 12:02:57.403160: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:983] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2020-11-06 12:02:57.403797: I tensorflow/compiler/xla/service/service.cc:168] XLA service 0x6c8e540 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# 2020-11-06 12:02:57.403828: I tensorflow/compiler/xla/service/service.cc:176]   StreamExecutor device (0): Tesla T4, Compute Capability 7.5
# 2020-11-06 12:02:57.404062: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:983] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2020-11-06 12:02:57.404563: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1639] Found device 0 with properties:
# name: Tesla T4 major: 7 minor: 5 memoryClockRate(GHz): 1.59
# pciBusID: 0000:00:04.0
# 2020-11-06 12:02:57.404864: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcudart.so.10.1
# 2020-11-06 12:02:57.620062: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcublas.so.10
# 2020-11-06 12:02:57.737111: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcufft.so.10
# 2020-11-06 12:02:57.789934: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcurand.so.10
# 2020-11-06 12:02:58.024487: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcusolver.so.10
# 2020-11-06 12:02:58.089659: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcusparse.so.10
# 2020-11-06 12:02:58.550775: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcudnn.so.7
# 2020-11-06 12:02:58.550985: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:983] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2020-11-06 12:02:58.551646: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:983] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2020-11-06 12:02:58.552184: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1767] Adding visible gpu devices: 0
# 2020-11-06 12:02:58.554797: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcudart.so.10.1
# 2020-11-06 12:02:58.556059: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1180] Device interconnect StreamExecutor with strength 1 edge matrix:
# 2020-11-06 12:02:58.556088: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1186]      0
# 2020-11-06 12:02:58.556099: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1199] 0:   N
# 2020-11-06 12:02:58.586329: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:983] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2020-11-06 12:02:58.586880: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:983] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2020-11-06 12:02:58.587375: W tensorflow/core/common_runtime/gpu/gpu_bfc_allocator.cc:39] Overriding allow_growth setting because the TF_FORCE_GPU_ALLOW_GROWTH environment variable is set. Original config value was 0.
# 2020-11-06 12:02:58.587434: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1325] Created TensorFlow device (/device:GPU:0 with 11718 MB memory) -> physical GPU (device: 0, name: Tesla T4, pci bus id: 0000:00:04.0, compute capability: 7.5)
# 2020-11-06 12:02:58.588404: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:983] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2020-11-06 12:02:58.588922: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1639] Found device 0 with properties:
# name: Tesla T4 major: 7 minor: 5 memoryClockRate(GHz): 1.59
# pciBusID: 0000:00:04.0
# 2020-11-06 12:02:58.588975: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcudart.so.10.1
# 2020-11-06 12:02:58.589003: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcublas.so.10
# 2020-11-06 12:02:58.589043: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcufft.so.10
# 2020-11-06 12:02:58.589070: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcurand.so.10
# 2020-11-06 12:02:58.589094: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcusolver.so.10
# 2020-11-06 12:02:58.589114: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcusparse.so.10
# 2020-11-06 12:02:58.589134: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcudnn.so.7
# 2020-11-06 12:02:58.589200: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:983] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2020-11-06 12:02:58.589706: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:983] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2020-11-06 12:02:58.590197: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1767] Adding visible gpu devices: 0
# 2020-11-06 12:02:58.590227: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1180] Device interconnect StreamExecutor with strength 1 edge matrix:
# 2020-11-06 12:02:58.590242: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1186]      0
# 2020-11-06 12:02:58.590255: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1199] 0:   N
# 2020-11-06 12:02:58.590354: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:983] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2020-11-06 12:02:58.590883: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:983] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2020-11-06 12:02:58.591390: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1325] Created TensorFlow device (/device:GPU:0 with 11718 MB memory) -> physical GPU (device: 0, name: Tesla T4, pci bus id: 0000:00:04.0, compute capability: 7.5)
# 2020-11-06 12:02:58.617423: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:983] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2020-11-06 12:02:58.617988: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1639] Found device 0 with properties:
# name: Tesla T4 major: 7 minor: 5 memoryClockRate(GHz): 1.59
# pciBusID: 0000:00:04.0
# 2020-11-06 12:02:58.618057: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcudart.so.10.1
# 2020-11-06 12:02:58.618085: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcublas.so.10
# 2020-11-06 12:02:58.618108: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcufft.so.10
# 2020-11-06 12:02:58.618130: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcurand.so.10
# 2020-11-06 12:02:58.618151: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcusolver.so.10
# 2020-11-06 12:02:58.618172: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcusparse.so.10
# 2020-11-06 12:02:58.618193: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcudnn.so.7
# 2020-11-06 12:02:58.618274: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:983] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2020-11-06 12:02:58.618783: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:983] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2020-11-06 12:02:58.619258: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1767] Adding visible gpu devices: 0
# 2020-11-06 12:02:58.619288: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1180] Device interconnect StreamExecutor with strength 1 edge matrix:
# 2020-11-06 12:02:58.619306: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1186]      0
# 2020-11-06 12:02:58.619316: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1199] 0:   N
# 2020-11-06 12:02:58.619416: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:983] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2020-11-06 12:02:58.619959: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:983] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2020-11-06 12:02:58.620465: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1325] Created TensorFlow device (/device:GPU:0 with 11718 MB memory) -> physical GPU (device: 0, name: Tesla T4, pci bus id: 0000:00:04.0, compute capability: 7.5)
# 2020-11-06 12:02:58.620857: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:983] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2020-11-06 12:02:58.621471: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1639] Found device 0 with properties:
# name: Tesla T4 major: 7 minor: 5 memoryClockRate(GHz): 1.59
# pciBusID: 0000:00:04.0
# 2020-11-06 12:02:58.621518: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcudart.so.10.1
# 2020-11-06 12:02:58.621543: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcublas.so.10
# 2020-11-06 12:02:58.621565: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcufft.so.10
# 2020-11-06 12:02:58.621587: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcurand.so.10
# 2020-11-06 12:02:58.621613: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcusolver.so.10
# 2020-11-06 12:02:58.621633: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcusparse.so.10
# 2020-11-06 12:02:58.621654: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcudnn.so.7
# 2020-11-06 12:02:58.621723: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:983] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2020-11-06 12:02:58.622303: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:983] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2020-11-06 12:02:58.622786: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1767] Adding visible gpu devices: 0
# 2020-11-06 12:02:58.622817: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1180] Device interconnect StreamExecutor with strength 1 edge matrix:
# 2020-11-06 12:02:58.622832: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1186]      0
# 2020-11-06 12:02:58.622845: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1199] 0:   N
# 2020-11-06 12:02:58.622929: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:983] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2020-11-06 12:02:58.623505: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:983] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2020-11-06 12:02:58.623976: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1325] Created TensorFlow device (/device:GPU:0 with 11718 MB memory) -> physical GPU (device: 0, name: Tesla T4, pci bus id: 0000:00:04.0, compute capability: 7.5)
# 2020-11-06 12:02:58.634035: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:983] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2020-11-06 12:02:58.634524: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1639] Found device 0 with properties:
# name: Tesla T4 major: 7 minor: 5 memoryClockRate(GHz): 1.59
# pciBusID: 0000:00:04.0
# 2020-11-06 12:02:58.634568: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcudart.so.10.1
# 2020-11-06 12:02:58.634591: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcublas.so.10
# 2020-11-06 12:02:58.634612: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcufft.so.10
# 2020-11-06 12:02:58.634635: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcurand.so.10
# 2020-11-06 12:02:58.634660: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcusolver.so.10
# 2020-11-06 12:02:58.634679: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcusparse.so.10
# 2020-11-06 12:02:58.634699: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcudnn.so.7
# 2020-11-06 12:02:58.634763: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:983] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2020-11-06 12:02:58.635306: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:983] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2020-11-06 12:02:58.635763: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1767] Adding visible gpu devices: 0
# 2020-11-06 12:02:58.635789: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1180] Device interconnect StreamExecutor with strength 1 edge matrix:
# 2020-11-06 12:02:58.635817: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1186]      0
# 2020-11-06 12:02:58.635827: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1199] 0:   N
# 2020-11-06 12:02:58.635930: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:983] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2020-11-06 12:02:58.636476: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:983] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2020-11-06 12:02:58.637041: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1325] Created TensorFlow device (/device:GPU:0 with 11718 MB memory) -> physical GPU (device: 0, name: Tesla T4, pci bus id: 0000:00:04.0, compute capability: 7.5)
# 2020-11-06 12:02:58.637396: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:983] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2020-11-06 12:02:58.638476: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1639] Found device 0 with properties:
# name: Tesla T4 major: 7 minor: 5 memoryClockRate(GHz): 1.59
# pciBusID: 0000:00:04.0
# 2020-11-06 12:02:58.638534: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcudart.so.10.1
# 2020-11-06 12:02:58.638559: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcublas.so.10
# 2020-11-06 12:02:58.638580: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcufft.so.10
# 2020-11-06 12:02:58.638600: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcurand.so.10
# 2020-11-06 12:02:58.638621: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcusolver.so.10
# 2020-11-06 12:02:58.638639: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcusparse.so.10
# 2020-11-06 12:02:58.638658: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcudnn.so.7
# 2020-11-06 12:02:58.638724: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:983] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2020-11-06 12:02:58.639347: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:983] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2020-11-06 12:02:58.639873: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1767] Adding visible gpu devices: 0
# 2020-11-06 12:02:58.639905: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1180] Device interconnect StreamExecutor with strength 1 edge matrix:
# 2020-11-06 12:02:58.639922: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1186]      0
# 2020-11-06 12:02:58.639934: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1199] 0:   N
# 2020-11-06 12:02:58.640055: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:983] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2020-11-06 12:02:58.640566: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:983] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2020-11-06 12:02:58.641053: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1325] Created TensorFlow device (/device:GPU:0 with 11718 MB memory) -> physical GPU (device: 0, name: Tesla T4, pci bus id: 0000:00:04.0, compute capability: 7.5)
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/onnx_tf/handlers/backend/reshape.py:26: where (from tensorflow.python.ops.array_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.where in 2.0, which has the same broadcast rule as np.where
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/onnx_tf/handlers/backend/reshape.py:31: sparse_to_dense (from tensorflow.python.ops.sparse_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Create a `tf.sparse.SparseTensor` and use `tf.sparse.to_dense` instead.
# 2020-11-06 12:02:58.711219: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:983] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2020-11-06 12:02:58.711701: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1639] Found device 0 with properties:
# name: Tesla T4 major: 7 minor: 5 memoryClockRate(GHz): 1.59
# pciBusID: 0000:00:04.0
# 2020-11-06 12:02:58.711752: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcudart.so.10.1
# 2020-11-06 12:02:58.711779: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcublas.so.10
# 2020-11-06 12:02:58.711800: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcufft.so.10
# 2020-11-06 12:02:58.711823: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcurand.so.10
# 2020-11-06 12:02:58.711842: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcusolver.so.10
# 2020-11-06 12:02:58.711861: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcusparse.so.10
# 2020-11-06 12:02:58.711879: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcudnn.so.7
# 2020-11-06 12:02:58.711945: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:983] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2020-11-06 12:02:58.712491: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:983] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2020-11-06 12:02:58.712925: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1767] Adding visible gpu devices: 0
# 2020-11-06 12:02:58.712952: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1180] Device interconnect StreamExecutor with strength 1 edge matrix:
# 2020-11-06 12:02:58.712967: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1186]      0
# 2020-11-06 12:02:58.712976: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1199] 0:   N
# 2020-11-06 12:02:58.713088: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:983] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2020-11-06 12:02:58.713628: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:983] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2020-11-06 12:02:58.714164: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1325] Created TensorFlow device (/device:GPU:0 with 11718 MB memory) -> physical GPU (device: 0, name: Tesla T4, pci bus id: 0000:00:04.0, compute capability: 7.5)
# 2020-11-06 12:02:58.714572: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:983] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2020-11-06 12:02:58.715079: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1639] Found device 0 with properties:
# name: Tesla T4 major: 7 minor: 5 memoryClockRate(GHz): 1.59
# pciBusID: 0000:00:04.0
# 2020-11-06 12:02:58.715123: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcudart.so.10.1
# 2020-11-06 12:02:58.715145: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcublas.so.10
# 2020-11-06 12:02:58.715166: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcufft.so.10
# 2020-11-06 12:02:58.715185: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcurand.so.10
# 2020-11-06 12:02:58.715204: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcusolver.so.10
# 2020-11-06 12:02:58.715222: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcusparse.so.10
# 2020-11-06 12:02:58.715241: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcudnn.so.7
# 2020-11-06 12:02:58.715308: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:983] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2020-11-06 12:02:58.715810: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:983] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2020-11-06 12:02:58.716305: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1767] Adding visible gpu devices: 0
# 2020-11-06 12:02:58.716341: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1180] Device interconnect StreamExecutor with strength 1 edge matrix:
# 2020-11-06 12:02:58.716356: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1186]      0
# 2020-11-06 12:02:58.716367: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1199] 0:   N
# 2020-11-06 12:02:58.716468: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:983] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2020-11-06 12:02:58.717006: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:983] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2020-11-06 12:02:58.717532: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1325] Created TensorFlow device (/device:GPU:0 with 11718 MB memory) -> physical GPU (device: 0, name: Tesla T4, pci bus id: 0000:00:04.0, compute capability: 7.5)
# 2020-11-06 12:02:58.742980: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:983] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2020-11-06 12:02:58.743542: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1639] Found device 0 with properties:
# name: Tesla T4 major: 7 minor: 5 memoryClockRate(GHz): 1.59
# pciBusID: 0000:00:04.0
# 2020-11-06 12:02:58.743590: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcudart.so.10.1
# 2020-11-06 12:02:58.743616: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcublas.so.10
# 2020-11-06 12:02:58.743639: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcufft.so.10
# 2020-11-06 12:02:58.743660: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcurand.so.10
# 2020-11-06 12:02:58.743681: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcusolver.so.10
# 2020-11-06 12:02:58.743701: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcusparse.so.10
# 2020-11-06 12:02:58.743722: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcudnn.so.7
# 2020-11-06 12:02:58.743790: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:983] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2020-11-06 12:02:58.744353: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:983] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2020-11-06 12:02:58.744826: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1767] Adding visible gpu devices: 0
# 2020-11-06 12:02:58.744852: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1180] Device interconnect StreamExecutor with strength 1 edge matrix:
# 2020-11-06 12:02:58.744870: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1186]      0
# 2020-11-06 12:02:58.744881: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1199] 0:   N
# 2020-11-06 12:02:58.744961: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:983] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2020-11-06 12:02:58.745543: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:983] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2020-11-06 12:02:58.746048: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1325] Created TensorFlow device (/device:GPU:0 with 11718 MB memory) -> physical GPU (device: 0, name: Tesla T4, pci bus id: 0000:00:04.0, compute capability: 7.5)
# 2020-11-06 12:02:58.746421: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:983] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2020-11-06 12:02:58.746902: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1639] Found device 0 with properties:
# name: Tesla T4 major: 7 minor: 5 memoryClockRate(GHz): 1.59
# pciBusID: 0000:00:04.0
# 2020-11-06 12:02:58.746946: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcudart.so.10.1
# 2020-11-06 12:02:58.746969: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcublas.so.10
# 2020-11-06 12:02:58.746993: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcufft.so.10
# 2020-11-06 12:02:58.747013: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcurand.so.10
# 2020-11-06 12:02:58.747067: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcusolver.so.10
# 2020-11-06 12:02:58.747089: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcusparse.so.10
# 2020-11-06 12:02:58.747109: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcudnn.so.7
# 2020-11-06 12:02:58.747167: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:983] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2020-11-06 12:02:58.747699: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:983] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2020-11-06 12:02:58.748206: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1767] Adding visible gpu devices: 0
# 2020-11-06 12:02:58.748233: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1180] Device interconnect StreamExecutor with strength 1 edge matrix:
# 2020-11-06 12:02:58.748251: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1186]      0
# 2020-11-06 12:02:58.748263: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1199] 0:   N
# 2020-11-06 12:02:58.748360: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:983] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2020-11-06 12:02:58.748897: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:983] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2020-11-06 12:02:58.749418: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1325] Created TensorFlow device (/device:GPU:0 with 11718 MB memory) -> physical GPU (device: 0, name: Tesla T4, pci bus id: 0000:00:04.0, compute capability: 7.5)
# 2020-11-06 12:02:58.774320: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:983] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2020-11-06 12:02:58.774803: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1639] Found device 0 with properties:
# name: Tesla T4 major: 7 minor: 5 memoryClockRate(GHz): 1.59
# pciBusID: 0000:00:04.0
# 2020-11-06 12:02:58.774846: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcudart.so.10.1
# 2020-11-06 12:02:58.774870: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcublas.so.10
# 2020-11-06 12:02:58.774890: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcufft.so.10
# 2020-11-06 12:02:58.774914: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcurand.so.10
# 2020-11-06 12:02:58.774934: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcusolver.so.10
# 2020-11-06 12:02:58.774953: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcusparse.so.10
# 2020-11-06 12:02:58.774972: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcudnn.so.7
# 2020-11-06 12:02:58.775059: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:983] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2020-11-06 12:02:58.775566: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:983] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2020-11-06 12:02:58.776028: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1767] Adding visible gpu devices: 0
# 2020-11-06 12:02:58.776055: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1180] Device interconnect StreamExecutor with strength 1 edge matrix:
# 2020-11-06 12:02:58.776070: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1186]      0
# 2020-11-06 12:02:58.776080: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1199] 0:   N
# 2020-11-06 12:02:58.776168: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:983] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2020-11-06 12:02:58.776676: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:983] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2020-11-06 12:02:58.777171: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1325] Created TensorFlow device (/device:GPU:0 with 11718 MB memory) -> physical GPU (device: 0, name: Tesla T4, pci bus id: 0000:00:04.0, compute capability: 7.5)
# 2020-11-06 12:02:58.777496: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:983] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2020-11-06 12:02:58.777965: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1639] Found device 0 with properties:
# name: Tesla T4 major: 7 minor: 5 memoryClockRate(GHz): 1.59
# pciBusID: 0000:00:04.0
# 2020-11-06 12:02:58.778003: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcudart.so.10.1
# 2020-11-06 12:02:58.778043: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcublas.so.10
# 2020-11-06 12:02:58.778066: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcufft.so.10
# 2020-11-06 12:02:58.778085: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcurand.so.10
# 2020-11-06 12:02:58.778102: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcusolver.so.10
# 2020-11-06 12:02:58.778120: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcusparse.so.10
# 2020-11-06 12:02:58.778137: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcudnn.so.7
# 2020-11-06 12:02:58.778196: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:983] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2020-11-06 12:02:58.778720: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:983] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2020-11-06 12:02:58.779216: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1767] Adding visible gpu devices: 0
# 2020-11-06 12:02:58.779246: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1180] Device interconnect StreamExecutor with strength 1 edge matrix:
# 2020-11-06 12:02:58.779263: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1186]      0
# 2020-11-06 12:02:58.779275: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1199] 0:   N
# 2020-11-06 12:02:58.779364: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:983] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2020-11-06 12:02:58.779869: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:983] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2020-11-06 12:02:58.780345: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1325] Created TensorFlow device (/device:GPU:0 with 11718 MB memory) -> physical GPU (device: 0, name: Tesla T4, pci bus id: 0000:00:04.0, compute capability: 7.5)
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/onnx_tf/handlers/backend_handler.py:182: div (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Deprecated in favor of operator or tf.math.divide.

# %% [markdown]
# **OR**
# Code in next block can also be used to convert onnx to tf freezegraph
# **It is not tested by me**

# %%
# load the model saved in onnx format
from onnx_tf.backend import prepare

model_onnx = onnx.load('eye_state_model_ONNX.onnx')
onnx.checker.check_model(model_onnx)

# prepare model for exporting to tensorFlow using tensorFlow backend
tf_rep = prepare(model_onnx)
start_time = mills()
print(tf_rep.run(dummy_input))
end_time = mills()
print(end_time - start_time)
print(tf_rep.inputs) # Input nodes to the model
print('-----')
print(tf_rep.outputs) # Output nodes from the model
print('-----')
print(tf_rep.tensor_dict) # All nodes in the model

# # export tensorFlow backend to tensorflow tf file
tf_rep.export_graph('eye_state_model_tensorFlow.pb')
tf_rep.run(dummy_input)
# Out:
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/onnx_tf/handlers/backend/ceil.py:10: The name tf.ceil is deprecated. Please use tf.math.ceil instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/onnx_tf/handlers/backend/depth_to_space.py:12: The name tf.depth_to_space is deprecated. Please use tf.compat.v1.depth_to_space instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/onnx_tf/handlers/backend/erf.py:9: The name tf.erf is deprecated. Please use tf.math.erf instead.
#
# WARNING:tensorflow:
# The TensorFlow contrib module will not be included in TensorFlow 2.0.
# For more information, please see:
#   * https://github.com/tensorflow/community/blob/master/rfcs/20180907-contrib-sunset.md
#   * https://github.com/tensorflow/addons
#   * https://github.com/tensorflow/io (for I/O related ops)
# If you depend on functionality not listed there, please file an issue.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/onnx_tf/handlers/backend/is_nan.py:9: The name tf.is_nan is deprecated. Please use tf.math.is_nan instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/onnx_tf/handlers/backend/log.py:10: The name tf.log is deprecated. Please use tf.math.log instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/onnx_tf/handlers/backend/random_normal.py:9: The name tf.random_normal is deprecated. Please use tf.random.normal instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/onnx_tf/handlers/backend/random_uniform.py:9: The name tf.random_uniform is deprecated. Please use tf.random.uniform instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/onnx_tf/handlers/backend/reciprocal.py:10: The name tf.reciprocal is deprecated. Please use tf.math.reciprocal instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/onnx_tf/handlers/backend/space_to_depth.py:12: The name tf.space_to_depth is deprecated. Please use tf.compat.v1.space_to_depth instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/onnx_tf/handlers/backend/upsample.py:15: The name tf.image.resize_images is deprecated. Please use tf.image.resize instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/onnx_tf/handlers/backend/xor.py:10: The name tf.logical_xor is deprecated. Please use tf.math.logical_xor instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/onnx_tf/backend.py:123: The name tf.placeholder is deprecated. Please use tf.compat.v1.placeholder instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/onnx_tf/handlers/backend/reshape.py:26: where (from tensorflow.python.ops.array_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.where in 2.0, which has the same broadcast rule as np.where
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/onnx_tf/handlers/backend/reshape.py:31: sparse_to_dense (from tensorflow.python.ops.sparse_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Create a `tf.sparse.SparseTensor` and use `tf.sparse.to_dense` instead.
# /usr/local/lib/python3.6/dist-packages/onnx_tf/common/__init__.py:89: UserWarning: onnx_tf.common.get_outputs_names is deprecated. It will be removed in future release. Use TensorflowGraph.get_outputs_names instead.
#   warnings.warn(message)
# /usr/local/lib/python3.6/dist-packages/onnx_tf/common/handler_helper.py:37: UserWarning: Unknown op ConstantFill in domain `ai.onnx`.
#   handler.ONNX_OP, handler.DOMAIN or "ai.onnx"))
# /usr/local/lib/python3.6/dist-packages/onnx_tf/common/handler_helper.py:34: UserWarning: Fail to get since_version of ConvInteger in domain `` with max_inclusive_version=9. Set to 1.
#   handler.ONNX_OP, handler.DOMAIN, version))
# /usr/local/lib/python3.6/dist-packages/onnx_tf/common/handler_helper.py:34: UserWarning: Fail to get since_version of DequantizeLinear in domain `` with max_inclusive_version=9. Set to 1.
#   handler.ONNX_OP, handler.DOMAIN, version))
# /usr/local/lib/python3.6/dist-packages/onnx_tf/common/handler_helper.py:34: UserWarning: Fail to get since_version of GatherND in domain `` with max_inclusive_version=9. Set to 1.
#   handler.ONNX_OP, handler.DOMAIN, version))
# /usr/local/lib/python3.6/dist-packages/onnx_tf/common/handler_helper.py:37: UserWarning: Unknown op ImageScaler in domain `ai.onnx`.
#   handler.ONNX_OP, handler.DOMAIN or "ai.onnx"))
# /usr/local/lib/python3.6/dist-packages/onnx_tf/common/handler_helper.py:34: UserWarning: Fail to get since_version of IsInf in domain `` with max_inclusive_version=9. Set to 1.
#   handler.ONNX_OP, handler.DOMAIN, version))
# /usr/local/lib/python3.6/dist-packages/onnx_tf/common/handler_helper.py:34: UserWarning: Fail to get since_version of MatMulInteger in domain `` with max_inclusive_version=9. Set to 1.
#   handler.ONNX_OP, handler.DOMAIN, version))
# /usr/local/lib/python3.6/dist-packages/onnx_tf/common/handler_helper.py:34: UserWarning: Fail to get since_version of Mod in domain `` with max_inclusive_version=9. Set to 1.
#   handler.ONNX_OP, handler.DOMAIN, version))
# /usr/local/lib/python3.6/dist-packages/onnx_tf/common/handler_helper.py:34: UserWarning: Fail to get since_version of NonMaxSuppression in domain `` with max_inclusive_version=9. Set to 1.
#   handler.ONNX_OP, handler.DOMAIN, version))
# /usr/local/lib/python3.6/dist-packages/onnx_tf/common/handler_helper.py:34: UserWarning: Fail to get since_version of QLinearConv in domain `` with max_inclusive_version=9. Set to 1.
#   handler.ONNX_OP, handler.DOMAIN, version))
# /usr/local/lib/python3.6/dist-packages/onnx_tf/common/handler_helper.py:34: UserWarning: Fail to get since_version of QLinearMatMul in domain `` with max_inclusive_version=9. Set to 1.
#   handler.ONNX_OP, handler.DOMAIN, version))
# /usr/local/lib/python3.6/dist-packages/onnx_tf/common/handler_helper.py:34: UserWarning: Fail to get since_version of QuantizeLinear in domain `` with max_inclusive_version=9. Set to 1.
#   handler.ONNX_OP, handler.DOMAIN, version))
# /usr/local/lib/python3.6/dist-packages/onnx_tf/common/handler_helper.py:34: UserWarning: Fail to get since_version of Range in domain `` with max_inclusive_version=9. Set to 1.
#   handler.ONNX_OP, handler.DOMAIN, version))
# /usr/local/lib/python3.6/dist-packages/onnx_tf/common/handler_helper.py:34: UserWarning: Fail to get since_version of Resize in domain `` with max_inclusive_version=9. Set to 1.
#   handler.ONNX_OP, handler.DOMAIN, version))
# /usr/local/lib/python3.6/dist-packages/onnx_tf/common/handler_helper.py:34: UserWarning: Fail to get since_version of ReverseSequence in domain `` with max_inclusive_version=9. Set to 1.
#   handler.ONNX_OP, handler.DOMAIN, version))
# /usr/local/lib/python3.6/dist-packages/onnx_tf/common/handler_helper.py:34: UserWarning: Fail to get since_version of Round in domain `` with max_inclusive_version=9. Set to 1.
#   handler.ONNX_OP, handler.DOMAIN, version))
# /usr/local/lib/python3.6/dist-packages/onnx_tf/common/handler_helper.py:34: UserWarning: Fail to get since_version of ScatterElements in domain `` with max_inclusive_version=9. Set to 1.
#   handler.ONNX_OP, handler.DOMAIN, version))
# /usr/local/lib/python3.6/dist-packages/onnx_tf/common/handler_helper.py:34: UserWarning: Fail to get since_version of ScatterND in domain `` with max_inclusive_version=9. Set to 1.
#   handler.ONNX_OP, handler.DOMAIN, version))
# /usr/local/lib/python3.6/dist-packages/onnx_tf/common/handler_helper.py:34: UserWarning: Fail to get since_version of ThresholdedRelu in domain `` with max_inclusive_version=9. Set to 1.
#   handler.ONNX_OP, handler.DOMAIN, version))
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/onnx_tf/handlers/backend_handler.py:182: div (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Deprecated in favor of operator or tf.math.divide.
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/onnx_tf/backend_rep.py:63: The name tf.Session is deprecated. Please use tf.compat.v1.Session instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/onnx_tf/backend_rep.py:81: The name tf.global_variables_initializer is deprecated. Please use tf.compat.v1.global_variables_initializer instead.
#
# Outputs(main_output=array([[[[0.433484  , 0.41998953, 0.4149863 , ..., 0.3574749 ,
#           0.31060505, 0.3940094 ],
#          [0.39806068, 0.40101647, 0.42159218, ..., 0.2849354 ,
#           0.28312412, 0.32416907],
#          [0.39887345, 0.4192745 , 0.39254504, ..., 0.24770588,
#           0.24658155, 0.30567044],
#          ...,
#          [0.40748835, 0.4289307 , 0.45143926, ..., 0.5031651 ,
#           0.4787489 , 0.46750182],
#          [0.39659274, 0.4151328 , 0.43215   , ..., 0.4823483 ,
#           0.46379876, 0.45471627],
#          [0.38823444, 0.37931353, 0.4206952 , ..., 0.45294517,
#           0.44677478, 0.44986472]],
#
#         [[0.4500058 , 0.44163424, 0.43215117, ..., 0.33709878,
#           0.34361005, 0.3636375 ],
#          [0.4268062 , 0.43772087, 0.430138  , ..., 0.35041553,
#           0.32852006, 0.36744022],
#          [0.44162235, 0.42279774, 0.40270382, ..., 0.28841946,
#           0.28787112, 0.33199662],
#          ...,
#          [0.50858176, 0.5370097 , 0.5129028 , ..., 0.65669465,
#           0.6492566 , 0.59633434],
#          [0.50811005, 0.52206975, 0.5117663 , ..., 0.65404737,
#           0.6409583 , 0.6093768 ],
#          [0.49453163, 0.5017092 , 0.4884455 , ..., 0.58998007,
#           0.57768553, 0.5573234 ]],
#
#         [[0.4851996 , 0.4703592 , 0.45153484, ..., 0.4091215 ,
#           0.39181116, 0.41483542],
#          [0.4595398 , 0.47712708, 0.44091487, ..., 0.4024052 ,
#           0.36503   , 0.40545255],
#          [0.4469937 , 0.43177968, 0.40793997, ..., 0.35849723,
#           0.33814263, 0.36444935],
#          ...,
#          [0.5841857 , 0.60553586, 0.56419826, ..., 0.7413946 ,
#           0.7393655 , 0.6698055 ],
#          [0.5939081 , 0.60024154, 0.56930774, ..., 0.7511037 ,
#           0.75267625, 0.6792095 ],
#          [0.5542367 , 0.5680796 , 0.54815024, ..., 0.67633796,
#           0.6736067 , 0.62465835]]]], dtype=float32))
# 14511
# ['main_input']
# -----
# ['main_output']
# -----
# {'15': <tf.Tensor 'Const:0' shape=(32, 8, 3, 3) dtype=float32>, '16': <tf.Tensor 'Const_1:0' shape=(32,) dtype=float32>, '17': <tf.Tensor 'Const_2:0' shape=(32, 8, 3, 3) dtype=float32>, '18': <tf.Tensor 'Const_3:0' shape=(32,) dtype=float32>, '19': <tf.Tensor 'Const_4:0' shape=(32, 8, 3, 3) dtype=float32>, '20': <tf.Tensor 'Const_5:0' shape=(32,) dtype=float32>, '21': <tf.Tensor 'Const_6:0' shape=(3, 8, 3, 3) dtype=float32>, '22': <tf.Tensor 'Const_7:0' shape=(3,) dtype=float32>, '58': <tf.Tensor 'Const_8:0' shape=(8, 3, 3, 3) dtype=float32>, '59': <tf.Tensor 'Const_9:0' shape=(8,) dtype=float32>, '61': <tf.Tensor 'Const_10:0' shape=(8, 8, 3, 3) dtype=float32>, '62': <tf.Tensor 'Const_11:0' shape=(8,) dtype=float32>, '63': <tf.Tensor 'Const_12:0' shape=() dtype=float32>, 'main_input': <tf.Tensor 'main_input:0' shape=(1, 3, 256, 256) dtype=float32>, '57': <tf.Tensor 'Add:0' shape=(1, 8, 256, 256) dtype=float32>, '25': <tf.Tensor 'Relu_1:0' shape=(1, 8, 256, 256) dtype=float32>, '60': <tf.Tensor 'Add_1:0' shape=(1, 8, 256, 256) dtype=float32>, '28': <tf.Tensor 'Relu_3:0' shape=(1, 8, 256, 256) dtype=float32>, '29': <tf.Tensor 'Add_2:0' shape=(1, 32, 256, 256) dtype=float32>, '30': <tf.Tensor 'Relu_5:0' shape=(1, 32, 256, 256) dtype=float32>, '31': <tf.Tensor 'Constant_6:0' shape=(6,) dtype=int64>, '32': <tf.Tensor 'Reshape_7:0' shape=(1, 8, 2, 2, 256, 256) dtype=float32>, '33': <tf.Tensor 'Transpose_8:0' shape=(1, 8, 256, 2, 256, 2) dtype=float32>, '34': <tf.Tensor 'Constant_9:0' shape=(4,) dtype=int64>, '35': <tf.Tensor 'Reshape_10:0' shape=(1, 8, 512, 512) dtype=float32>, '36': <tf.Tensor 'Add_5:0' shape=(1, 32, 512, 512) dtype=float32>, '37': <tf.Tensor 'Relu_12:0' shape=(1, 32, 512, 512) dtype=float32>, '38': <tf.Tensor 'Constant_13:0' shape=(6,) dtype=int64>, '39': <tf.Tensor 'Reshape_14:0' shape=(1, 8, 2, 2, 512, 512) dtype=float32>, '40': <tf.Tensor 'Transpose_15:0' shape=(1, 8, 512, 2, 512, 2) dtype=float32>, '41': <tf.Tensor 'Constant_16:0' shape=(4,) dtype=int64>, '42': <tf.Tensor 'Reshape_17:0' shape=(1, 8, 1024, 1024) dtype=float32>, '43': <tf.Tensor 'Add_8:0' shape=(1, 32, 1024, 1024) dtype=float32>, '44': <tf.Tensor 'Relu_19:0' shape=(1, 32, 1024, 1024) dtype=float32>, '45': <tf.Tensor 'Constant_20:0' shape=(6,) dtype=int64>, '46': <tf.Tensor 'Reshape_21:0' shape=(1, 8, 2, 2, 1024, 1024) dtype=float32>, '47': <tf.Tensor 'Transpose_22:0' shape=(1, 8, 1024, 2, 1024, 2) dtype=float32>, '48': <tf.Tensor 'Constant_23:0' shape=(4,) dtype=int64>, '49': <tf.Tensor 'Reshape_24:0' shape=(1, 8, 2048, 2048) dtype=float32>, '50': <tf.Tensor 'Add_11:0' shape=(1, 3, 2048, 2048) dtype=float32>, '51': <tf.Tensor 'Tanh_26:0' shape=(1, 3, 2048, 2048) dtype=float32>, '52': <tf.Tensor 'Constant_27:0' shape=() dtype=float32>, '53': <tf.Tensor 'Add_28:0' shape=(1, 3, 2048, 2048) dtype=float32>, 'main_output': <tf.Tensor 'Div_29:0' shape=(1, 3, 2048, 2048) dtype=float32>}
# Outputs(main_output=array([[[[0.433484  , 0.41998953, 0.4149863 , ..., 0.3574749 ,
#           0.31060505, 0.3940094 ],
#          [0.39806068, 0.40101647, 0.42159218, ..., 0.2849354 ,
#           0.28312412, 0.32416907],
#          [0.39887345, 0.4192745 , 0.39254504, ..., 0.24770588,
#           0.24658155, 0.30567044],
#          ...,
#          [0.40748835, 0.4289307 , 0.45143926, ..., 0.5031651 ,
#           0.4787489 , 0.46750182],
#          [0.39659274, 0.4151328 , 0.43215   , ..., 0.4823483 ,
#           0.46379876, 0.45471627],
#          [0.38823444, 0.37931353, 0.4206952 , ..., 0.45294517,
#           0.44677478, 0.44986472]],
#
#         [[0.4500058 , 0.44163424, 0.43215117, ..., 0.33709878,
#           0.34361005, 0.3636375 ],
#          [0.4268062 , 0.43772087, 0.430138  , ..., 0.35041553,
#           0.32852006, 0.36744022],
#          [0.44162235, 0.42279774, 0.40270382, ..., 0.28841946,
#           0.28787112, 0.33199662],
#          ...,
#          [0.50858176, 0.5370097 , 0.5129028 , ..., 0.65669465,
#           0.6492566 , 0.59633434],
#          [0.50811005, 0.52206975, 0.5117663 , ..., 0.65404737,
#           0.6409583 , 0.6093768 ],
#          [0.49453163, 0.5017092 , 0.4884455 , ..., 0.58998007,
#           0.57768553, 0.5573234 ]],
#
#         [[0.4851996 , 0.4703592 , 0.45153484, ..., 0.4091215 ,
#           0.39181116, 0.41483542],
#          [0.4595398 , 0.47712708, 0.44091487, ..., 0.4024052 ,
#           0.36503   , 0.40545255],
#          [0.4469937 , 0.43177968, 0.40793997, ..., 0.35849723,
#           0.33814263, 0.36444935],
#          ...,
#          [0.5841857 , 0.60553586, 0.56419826, ..., 0.7413946 ,
#           0.7393655 , 0.6698055 ],
#          [0.5939081 , 0.60024154, 0.56930774, ..., 0.7511037 ,
#           0.75267625, 0.6792095 ],
#          [0.5542367 , 0.5680796 , 0.54815024, ..., 0.67633796,
#           0.6736067 , 0.62465835]]]], dtype=float32))

# %% [markdown]
# List all Operations in a model

# %%
# export_dir = './saved'
# graph_pb = '/content/eye_state_model_tensorFlow.pb'

# builder = tf.saved_model.builder.SavedModelBuilder(export_dir)

# with tf.gfile.GFile(graph_pb, "rb") as f:
#     graph_def = tf.GraphDef()
#     graph_def.ParseFromString(f.read())
#     [n.name for n in tf.get_default_graph().as_graph_def().node]

# for i in tf.get_default_graph().get_operations():
#     print(i)
# print(tf.get_default_graph())

# %%
# # from PIL import Image
# # print('Image 1:')
# # img = Image.open('/content/dataset_facialImages/test/CloseFace/closed_eye_0089.jpg_face_1.jpg')
# # display(dummy_input)
# # print(np.asarray(img, dtype=np.float32)[np.newaxis, np.newaxis, :, :].shape)
# with tf.device('/CPU:0'):
#     for e in 'abcde':
#         output = tf_rep.run(dummy_input)
# for e in 'abcde':
#     print(model(dummy_input))
# print('The digit is classified as ', output)#np.argmax(output))

# %% [markdown]
# ## Convert the model to TensorFlow Lite
# Tensorflow Lite is designed to run on mobiles and other embedded systems with limited computing power and resources it do this by converting the model to specific format and introducing new types of optimization techniques. So we must have to save the model to those specific formats.
# TensorFlow saves the model in reduced file size and use different optimization techniques by not changing the accuracy. Optionaly we can more increase the speed of model with some trade offs but this is optional so we will tell about it in future sections
# ####**TensorFlow Lite Converter**
# This converter is the Python API which convert the TensorFlow Model to TensorFlow Lite Format it also introduce some optimization techniques which we will follow in coming Sections

# %%
import tensorflow as tf

# %%
import tensorflow as tf
# make a converter object from the saved tensorflow file
converter = tf.lite.TFLiteConverter.from_frozen_graph('/content/eye_state_model_tensorFlow.pb', #TensorFlow freezegraph .pb model file
                                                      input_arrays=['main_input'], # name of input arrays as defined in torch.onnx.export function before.
                                                      output_arrays=['main_output']  # name of output arrays defined in torch.onnx.export function before.
                                                      )
# tell converter which type of optimization techniques to use
# converter.optimizations = [tf.lite.Optimize.DEFAULT]
# to view the best option for optimization read documentation of tflite about optimization
# go to this link https://www.tensorflow.org/lite/guide/get_started#4_optimize_your_model_optional

# convert the model 
tf_lite_model = converter.convert()
# save the converted model 
open('/content/eye_state_model_tensorFlow.tflite', 'wb').write(tf_lite_model)
# Out:
# ---------------------------------------------------------------------------
# ConverterError                            Traceback (most recent call last)
# <ipython-input-48-08383f968a65> in <module>()
#      11
#      12 # convert the model
# ---> 13 tf_lite_model = converter.convert()
#      14 # save the converted model
#      15 open('/content/eye_state_model_tensorFlow.tflite', 'wb').write(tf_lite_model)
#
# /tensorflow-1.15.2/python3.6/tensorflow_core/lite/python/lite.py in convert(self)
#     981           input_tensors=self._input_tensors,
#     982           output_tensors=self._output_tensors,
# --> 983           **converter_kwargs)
#     984     else:
#     985       result = _toco_convert_graph_def(
#
# /tensorflow-1.15.2/python3.6/tensorflow_core/lite/python/convert.py in toco_convert_impl(input_data, input_tensors, output_tensors, enable_mlir_converter, *args, **kwargs)
#     447       input_data.SerializeToString(),
#     448       debug_info_str=debug_info_str,
# --> 449       enable_mlir_converter=enable_mlir_converter)
#     450   return data
#     451
#
# /tensorflow-1.15.2/python3.6/tensorflow_core/lite/python/convert.py in toco_convert_protos(model_flags_str, toco_flags_str, input_data_str, debug_info_str, enable_mlir_converter)
#     198       stdout = _try_convert_to_unicode(stdout)
#     199       stderr = _try_convert_to_unicode(stderr)
# --> 200       raise ConverterError("See console for info.\n%s\n%s\n" % (stdout, stderr))
#     201   finally:
#     202     # Must manually cleanup files.
#
# ConverterError: See console for info.
# 2020-11-06 12:05:31.354208: F tensorflow/lite/toco/import_tensorflow.cc:2679] Check failed: status.ok() Unexpected value for attribute 'data_format'. Expected 'NHWC'
# Fatal Python error: Aborted
#
# Current thread 0x00007f2fc6801780 (most recent call first):
#   File "/tensorflow-1.15.2/python3.6/tensorflow_core/lite/toco/python/toco_from_protos.py", line 52 in execute
#   File "/usr/local/lib/python3.6/dist-packages/absl/app.py", line 251 in _run_main
#   File "/usr/local/lib/python3.6/dist-packages/absl/app.py", line 300 in run
#   File "/tensorflow-1.15.2/python3.6/tensorflow_core/python/platform/app.py", line 40 in run
#   File "/tensorflow-1.15.2/python3.6/tensorflow_core/lite/toco/python/toco_from_protos.py", line 89 in main
#   File "/tensorflow-1.15.2/python3.6/bin/toco_from_protos", line 8 in <module>
# Aborted (core dumped)

# %% [markdown]
# ## Inference of TensorFlow Lite model with Python

# %%
import numpy as np
import tensorflow as tf
# Load TFLite model and allocate tensors.
interpreter = tf.lite.Interpreter(model_path="/content/eye_state_model_tensorFlow.tflite")
interpreter.allocate_tensors()

# Get input and output tensors.
input_details = interpreter.get_input_details()
output_details = interpreter.get_output_details()

# Test model on random input data.
input_shape = input_details[0]['shape']
print(input_details)
# input_data = np.array(np.random.random_sample(input_shape), dtype=np.float32)
input_data = dummy_input.numpy()
interpreter.set_tensor(input_details[0]['index'], input_data)
start_time = mills()

interpreter.invoke()

# The function `get_tensor()` returns a copy of the tensor data.
# Use `tensor()` in order to get a pointer to the tensor.
output_data = interpreter.get_tensor(output_details[0]['index'])
end_time = mills()
print("Time taken to one inference in milliseconds", end_time - start_time)
print("output of model",output_data)

# %% [markdown]
# Below blocks are used to run inference on single image

# %%
import torch
from torchvision import transforms
transform = transforms.Compose([
        transforms.CenterCrop(2256), # center crop every image to 224 pixels
        transforms.ToTensor(), # convert the image to Tensor
        transforms.Normalize((0.5,0.5,0.5), (0.5,0.5,0.5))                       
])

# %%
f = tensor.view(1,224,224,3 )
print(f.shape)

# %%
from PIL import Image
img = Image.open('/content/obama.jpeg')
img = img.convert('RGB')
img.save('/content/tst3.jpg')
tensor = transform(img)

# if gpu_available:
#     tensor = tensor.cuda()

print(tensor.shape)
tensor.unsqueeze_(0)
print(tensor.shape)
# print(model(tensor))
dummy_input = tensor

# %%
dummy_input.shape

# %%
img.save('/content/benazir.png')

# %%
model = model.cpu()
torch.save(model.state_dict(), 'state_dict.pt')

# %%
del model

# %%
model = torchvision.models.mobilenet_v2(pretrained=True)
model.classifier[1] = nn.Linear(in_features=model.classifier[1].in_features, out_features=2)

# %%
# vgg19
model = torchvision.models.vgg19(pretrained=True)
model.classifier[6] = model.classifier[6] = nn.Linear(4096,2)
# Out:
# Downloading: "https://download.pytorch.org/models/vgg19-dcbb9e9d.pth" to /root/.cache/torch/checkpoints/vgg19-dcbb9e9d.pth
# HBox(children=(FloatProgress(value=0.0, max=574673361.0), HTML(value='')))

# %%
model.load_state_dict(torch.load('state_dict.pt', map_location='cpu'))
# Out:
# <All keys matched successfully>

# %%
# !git clone https://github.com/tensorflow/examples.git
# Out:
# Cloning into 'examples'...
# remote: Enumerating objects: 142, done.
# remote: Counting objects: 100% (142/142), done.
# remote: Compressing objects: 100% (125/125), done.
# remote: Total 10440 (delta 55), reused 90 (delta 15), pack-reused 10298
# Receiving objects: 100% (10440/10440), 18.76 MiB | 21.63 MiB/s, done.
# Resolving deltas: 100% (5389/5389), done.

# %%
# !zip -r f.zip /content/examples/lite/examples/image_classification/android/images/
# Out:
# updating: content/examples/lite/examples/image_classification/android/images/ (stored 0%)
#   adding: content/examples/lite/examples/image_classification/android/images/classifydemo_img5.png (deflated 2%)
#   adding: content/examples/lite/examples/image_classification/android/images/classifydemo_img8.png (deflated 6%)
#   adding: content/examples/lite/examples/image_classification/android/images/classifydemo_img7.png (deflated 5%)
#   adding: content/examples/lite/examples/image_classification/android/images/classifydemo_img2.png (deflated 5%)
#   adding: content/examples/lite/examples/image_classification/android/images/classifydemo_img1.png (deflated 10%)
#   adding: content/examples/lite/examples/image_classification/android/images/classifydemo_img4.png (deflated 1%)
#   adding: content/examples/lite/examples/image_classification/android/images/classifydemo_img6.png (deflated 14%)
