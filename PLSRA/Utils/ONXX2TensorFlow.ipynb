# %%
# 参考 https://github.com/onnx/onnx-tensorflow#installation

# %%
# !pip install tensorflow==2.2.0

# %%
import tensorflow as tf
print(tf.__version__)

# %%
# !pip install onnx-tf

# %%
# !pip install tensorflow-addons

# %%
# !git clone https://github.com/onnx/onnx-tensorflow.git
# Out:
# fatal: destination path 'onnx-tensorflow' already exists and is not an empty directory.

# %%
# %cd onnx-tensorflow/
# Out:
# /content/onnx-tensorflow

# %%
pip install -e .

# %%
# !onnx-tf convert -i "/content/drive/My Drive/data/test/8xSRGANmodel.onnx" -o "/content/drive/My Drive/data/test/8xSRGANmodel.pb"
# Out:
# 2020-11-06 05:18:41,856 - onnx-tf - INFO - Start converting onnx pb to tf pb:
# 2020-11-06 05:18:42.195013: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcuda.so.1
# 2020-11-06 05:18:42.256237: E tensorflow/stream_executor/cuda/cuda_driver.cc:313] failed call to cuInit: CUDA_ERROR_NO_DEVICE: no CUDA-capable device is detected
# 2020-11-06 05:18:42.256352: I tensorflow/stream_executor/cuda/cuda_diagnostics.cc:156] kernel driver does not appear to be running on this host (e7b6b5356abd): /proc/driver/nvidia/version does not exist
# 2020-11-06 05:18:42.256863: I tensorflow/core/platform/cpu_feature_guard.cc:143] Your CPU supports instructions that this TensorFlow binary was not compiled to use: AVX2 FMA
# 2020-11-06 05:18:42.263583: I tensorflow/core/platform/profile_utils/cpu_utils.cc:102] CPU Frequency: 2300000000 Hz
# ...
